# %%
import data as d
import matplotlib as plt
import visualization as v

# %matplotlib inline
plt.rcParams.update({'font.size': 17})

df = v.distances_donut()
v.boxplot_donut_distances(df, "L1", )
# Out:
# 1574758534
# nsamps 3750 refsamps 3844
# Regularizer 0.016129032258072506
# Rnvp
# Constructing dataset
# fitting
#   0 5121.948
#   1 971.8609
#   2 4523.668
#   3 2352.7988
#   4 1439.4861
#   5 1240.2572
#   6 1760.7087
#   7 1985.4617
#   8 1796.4146
#   9 1316.783
#  10 860.07947
#  11 804.85706
#  12 978.6902
#  13 1042.4464
#  14 998.179
#  15 895.1361
#  16 805.001
#  17 744.1157
#  18 686.3014
#  19 646.03955
#  20 649.60913
#  21 673.42755
#  22 660.55884
#  23 598.6161
#  24 532.5224
#  25 502.18146
#  26 497.56183
#  27 489.80255
#  28 467.25232
#  29 429.33215
#  30 384.01685
#  31 349.907
#  32 329.27527
#  33 306.5218
#  34 279.66028
#  35 252.0099
#  36 217.80615
#  37 182.66428
#  38 156.1571
#  39 127.49133
#  40 92.997826
#  41 58.396893
#  42 22.48515
#  43 -4.463065
#  44 -29.278786
#  45 -58.72946
#  46 -86.36368
#  47 -102.038025
#  48 -109.402435
#  49 -126.20311
#  50 -147.00497
#  51 -160.30194
#  52 -178.08025
#  53 -207.88446
#  54 -245.0046
# ...

# %%
v.boxplot_donut_distances(df, "L1", )

# %%
# !pwd
# Out:
# /home/ischuster/software/python/Kernel_preimage_operator_code/rkhsop/experiments
